# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %% [markdown]
# # Data Preparation and Cleaning

# %%
raw_data = pd.read_csv(r'obesity.csv')
raw_data
# Out:
#       Gender        Age  family_history_with_overweight  FAVC  FCVC  NCP  \
# 0          0  21.000000                               1     0   2.0  3.0
# 1          0  21.000000                               1     0   3.0  3.0
# 2          1  23.000000                               1     0   2.0  3.0
# 3          1  27.000000                               0     0   3.0  3.0
# 4          1  22.000000                               0     0   2.0  1.0
# ...      ...        ...                             ...   ...   ...  ...
# 2106       0  20.976842                               1     1   3.0  3.0
# 2107       0  21.982942                               1     1   3.0  3.0
# 2108       0  22.524036                               1     1   3.0  3.0
# 2109       0  24.361936                               1     1   3.0  3.0
# 2110       0  23.664709                               1     1   3.0  3.0
#
#       CAEC  SMOKE      CH2O  SCC       FAF       TUE  CALC  Automobile  Bike  \
# ...

# %%
raw_data.shape
# Out:
# (2111, 19)

# %%
raw_data.columns
# Out:
# Index(['Gender', 'Age', 'family_history_with_overweight', 'FAVC', 'FCVC',
#        'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC',
#        'Automobile', 'Bike', 'Motorbike', 'Public_Transportation', 'Walking',
#        'NObeyesdad'],
#       dtype='object')

# %%
raw_data.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# Automobile                        0
# Bike                              0
# Motorbike                         0
# Public_Transportation             0
# Walking                           0
# NObeyesdad                        0
# dtype: int64

# %%
raw_data.duplicated().sum()
# Out:
# 29

# %%
raw_data.drop_duplicates(inplace=True)

# %%
raw_data.reset_index(drop=True, inplace=True)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2082 entries, 0 to 2081
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2082 non-null   int64
#  1   Age                             2082 non-null   float64
#  2   family_history_with_overweight  2082 non-null   int64
#  3   FAVC                            2082 non-null   int64
#  4   FCVC                            2082 non-null   float64
#  5   NCP                             2082 non-null   float64
#  6   CAEC                            2082 non-null   int64
#  7   SMOKE                           2082 non-null   int64
#  8   CH2O                            2082 non-null   float64
#  9   SCC                             2082 non-null   int64
#  10  FAF                             2082 non-null   float64
#  11  TUE                             2082 non-null   float64
# ...

# %%
for index in range(len(raw_data['Gender'])):
    if raw_data['Gender'].loc[index]:
        raw_data['Gender'].loc[index] = 'Male'
    else:
        raw_data['Gender'].loc[index] = 'Female'

raw_data
# Out:
# C:\Users\MR ADEMOLA\AppData\Local\Temp\ipykernel_8400\3958894208.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['Gender'].loc[index] = 'Female'
#       Gender        Age  family_history_with_overweight  FAVC  FCVC  NCP  \
# 0     Female  21.000000                               1     0   2.0  3.0
# 1     Female  21.000000                               1     0   3.0  3.0
# 2       Male  23.000000                               1     0   2.0  3.0
# 3       Male  27.000000                               0     0   3.0  3.0
# 4       Male  22.000000                               0     0   2.0  1.0
# ...      ...        ...                             ...   ...   ...  ...
# 2077  Female  20.976842                               1     1   3.0  3.0
# ...

# %%
for index in range(len(raw_data['family_history_with_overweight'])):
    if raw_data['family_history_with_overweight'].loc[index]:
        raw_data['family_history_with_overweight'].loc[index] = 'Yes'
    else:
        raw_data['family_history_with_overweight'].loc[index] = 'No'
        
for index in range(len(raw_data['SMOKE'])):
    if raw_data['SMOKE'].loc[index]:
        raw_data['SMOKE'].loc[index] = 'Yes'
    else:
        raw_data['SMOKE'].loc[index] = 'No'      

for index in range(len(raw_data['Automobile'])):
    if raw_data['Automobile'].loc[index]:
        raw_data['Automobile'].loc[index] = 'Yes'
    else:
        raw_data['Automobile'].loc[index] = 'No'
        
for index in range(len(raw_data['Bike'])):
    if raw_data['Bike'].loc[index]:
        raw_data['Bike'].loc[index] = 'Yes'
    else:
        raw_data['Bike'].loc[index] = 'No'      

for index in range(len(raw_data['Motorbike'])):
    if raw_data['Motorbike'].loc[index]:
        raw_data['Motorbike'].loc[index] = 'Yes'
    else:
        raw_data['Motorbike'].loc[index] = 'No' 

for index in range(len(raw_data['Public_Transportation'])):
    if raw_data['Public_Transportation'].loc[index]:
        raw_data['Public_Transportation'].loc[index] = 'Yes'
    else:
        raw_data['Public_Transportation'].loc[index] = 'No'
        
for index in range(len(raw_data['Walking'])):
    if raw_data['Walking'].loc[index]:
        raw_data['Walking'].loc[index] = 'Yes'
    else:
        raw_data['Walking'].loc[index] = 'No'
        
for index in range(len(raw_data['NObeyesdad'])):
    if raw_data['NObeyesdad'].loc[index]:
        raw_data['NObeyesdad'].loc[index] = 'Yes'
    else:
        raw_data['NObeyesdad'].loc[index] = 'No'

for index in range(len(raw_data['CAEC'])):
    if raw_data['CAEC'].loc[index]:
        raw_data['CAEC'].loc[index] = 'Yes'
    else:
        raw_data['CAEC'].loc[index] = 'No'
        
for index in range(len(raw_data['FAVC'])):
    if raw_data['FAVC'].loc[index]:
        raw_data['FAVC'].loc[index] = 'Yes'
    else:
        raw_data['FAVC'].loc[index] = 'No'
        
for index in range(len(raw_data['CH2O'])):
    if raw_data['CH2O'].loc[index]:
        raw_data['CH2O'].loc[index] = 'Yes'
    else:
        raw_data['CH2O'].loc[index] = 'No'
        
for index in range(len(raw_data['SCC'])):
    if raw_data['SCC'].loc[index]:
        raw_data['SCC'].loc[index] = 'Yes'
    else:
        raw_data['SCC'].loc[index] = 'No'
# Out:
# C:\Users\MR ADEMOLA\AppData\Local\Temp\ipykernel_8400\3454278976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['family_history_with_overweight'].loc[index] = 'Yes'
# C:\Users\MR ADEMOLA\AppData\Local\Temp\ipykernel_8400\3454278976.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['SMOKE'].loc[index] = 'No'
# C:\Users\MR ADEMOLA\AppData\Local\Temp\ipykernel_8400\3454278976.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
raw_data.sample(5)
# Out:
#       Gender        Age family_history_with_overweight FAVC      FCVC  \
# 540     Male  18.000000                             No  Yes  2.823179
# 1261    Male  22.975526                            Yes  Yes  2.000000
# 1676    Male  23.254934                            Yes  Yes  3.000000
# 1143  Female  34.176795                            Yes  Yes  2.796060
# 581     Male  17.469417                            Yes  Yes  2.336044
#
#            NCP CAEC SMOKE CH2O SCC       FAF       TUE  CALC Automobile Bike  \
# 540   3.000000  Yes    No  Yes  No  1.252472  1.000000     1         No   No
# 1261  3.000000  Yes    No  Yes  No  1.814869  1.066603     0         No   No
# 1676  2.280545  Yes    No  Yes  No  0.932783  0.000000     1         No   No
# 1143  1.971472  Yes    No  Yes  No  0.935217  0.704637     0        Yes   No
# 581   4.000000  Yes    No  Yes  No  2.000000  0.133005     0        Yes   No
#
#      Motorbike Public_Transportation Walking NObeyesdad
# ...

# %%
raw_data.rename(columns={'NObeyesdad':'Obese'}, inplace=True)
raw_data.rename(columns={'FAVC':'frequently_consumed_high_calorie'}, inplace=True)
raw_data.rename(columns={'FCVC':'frequency_of_consumpton_of_vegetables'}, inplace=True)
raw_data.rename(columns={'NCP':'nursing_care_plan'}, inplace=True)
raw_data.rename(columns={'SCC':'calories_consumption_monitoring'}, inplace=True)
raw_data.rename(columns={'CH2O':'amount_of_water_consumption'}, inplace=True)

# nursing care plan is defined as assess weight and blood pressure once or twice a week!
# CAEC; CAE Comorbidities ; children with newly diagnosed CAE have higher chances oof overweight and obesity

# %%
raw_data
# Out:
#       Gender        Age family_history_with_overweight  \
# 0     Female  21.000000                            Yes
# 1     Female  21.000000                            Yes
# 2       Male  23.000000                            Yes
# 3       Male  27.000000                             No
# 4       Male  22.000000                             No
# ...      ...        ...                            ...
# 2077  Female  20.976842                            Yes
# 2078  Female  21.982942                            Yes
# 2079  Female  22.524036                            Yes
# 2080  Female  24.361936                            Yes
# 2081  Female  23.664709                            Yes
#
#      frequently_consumed_high_calorie  frequency_of_consumpton_of_vegetables  \
# 0                                  No                                    2.0
# 1                                  No                                    3.0
# ...

# %%
raw_data.corr(numeric_only=True)
# Out:
#                                             Age  \
# Age                                    1.000000
# frequency_of_consumpton_of_vegetables  0.013581
# nursing_care_plan                     -0.054018
# FAF                                   -0.147056
# TUE                                   -0.305223
# CALC                                   0.044840
#
#                                        frequency_of_consumpton_of_vegetables  \
# Age                                                                 0.013581
# frequency_of_consumpton_of_vegetables                               1.000000
# nursing_care_plan                                                   0.034056
# FAF                                                                 0.022346
# TUE                                                                -0.104986
# CALC                                                                0.064160
#
#                                        nursing_care_plan       FAF       TUE  \
# ...

# %%
raw_data.describe()
# Out:
#                Age  frequency_of_consumpton_of_vegetables  nursing_care_plan  \
# count  2082.000000                            2082.000000        2082.000000
# mean     24.364024                               2.421998           2.699501
# std       6.371823                               0.534010           0.764387
# min      14.000000                               1.000000           1.000000
# 25%      19.935311                               2.000000           2.695560
# 50%      22.851747                               2.396772           3.000000
# 75%      26.000000                               3.000000           3.000000
# max      61.000000                               3.000000           4.000000
#
#                FAF          TUE         CALC
# count  2082.000000  2082.000000  2082.000000
# mean      1.011402     0.664147     0.730067
# std       0.853676     0.608143     0.517032
# min       0.000000     0.000000     0.000000
# 25%       0.120520     0.000000     0.000000
# ...

# %% [markdown]
# # Data Exploration and Visualization

# %%
sns.countplot(data=raw_data, x='Gender')
plt.title('Total Sex Distribution');

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=raw_data, x='Age', hue='Gender')
plt.title('Age Distribtuion accoording to Gender');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=raw_data, x='Obese', hue='Gender')
plt.title('Distribution of Obese people according to gender');

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=raw_data, x='family_history_with_overweight', hue='Obese')
plt.title('Obese family history distribution');

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=raw_data, x='Obese', y=raw_data.index, hue='Walking')
plt.title('Relationship between obese and walking');

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=raw_data, x='Obese', y=raw_data.index, hue='Public_Transportation')
plt.title('Relationship between obese and Public_Transportation');

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=raw_data, x='Obese', y=raw_data.index, hue='calories_consumption_monitoring')
plt.title('Relationship between obese and SCC');

# %% [markdown]
# # Questions and Answers

# %% [markdown]
# ## 1. How many people in the dataset are obese and not?

# %%
raw_data['Obese'].value_counts()
# Out:
# No     1110
# Yes     972
# Name: Obese, dtype: int64

# %%
print('''Number of obese people: {}
Number of people not obese: {}'''.format(raw_data['Obese'].value_counts()[1], raw_data['Obese'].value_counts()[0]))
# Out:
# Number of obese people: 972
# Number of people not obese: 1110

# %% [markdown]
# ## 2. How many Obese people has a family history of overweight?

# %%
a = raw_data[(raw_data['Obese'] == 'Yes') & (raw_data['family_history_with_overweight'] == 'Yes')].shape
a
# Out:
# (964, 19)

# %%
print('Number of obese people with family history of overweight: {}'.format(a[0]))
# Out:
# Number of obese people with family history of overweight: 964

# %% [markdown]
# ## 3. How many obese people smoke?

# %%
b = raw_data[(raw_data['Obese'] == 'Yes') & (raw_data['SMOKE'] == 'Yes')].shape
b
# Out:
# (22, 19)

# %%
print('Number of obese people that smoke: {}'.format(b[0]))
# Out:
# Number of obese people that smoke: 22

# %% [markdown]
# ## 4. What is the relationship of those that smoke and obesity?

# %%
print('''
Number of obese people that smoke: {}
Number of Obese people that don't smoke: {}

Answer: Smoking doesn't make one obese neither those it contribute to weight gain'''.format(b[0], (raw_data['Obese'].value_counts()[1] - b[0])))
# Out:
# Number of obese people that smoke: 22
# Number of Obese people that don't smoke: 950
#
# Answer: Smoking doesn't make one obese neither those it contribute to weight gain

# %% [markdown]
# ## 5. what's the number of obese people who walk and not?

# %%
c = raw_data[(raw_data['Obese'] == 'Yes') & (raw_data['Walking'] == 'Yes')].shape
d = raw_data[(raw_data['Obese'] == 'Yes') & (raw_data['Walking'] == 'No')].shape
c,d
# Out:
# ((3, 19), (969, 19))

# %%
print('''
Number of obese people that walk: {}
Number of obese people that don't walk: {}
'''.format(c[0], d[0]))
# Out:
# Number of obese people that walk: 3
# Number of obese people that don't walk: 969

# %% [markdown]
# # Inferences and Conclusions
#
# > 1. Both Males and Females are equally prone to obesity, indicating that gender does not significantly affect obesity rates.
#
# > 2. Individuals who do not engage in regular physical activity have a higher likelihood of gaining weight. Those who use public transport or engage in regular exercise(e.g walking or cycling) are less likely to be obese.
#
# > 3. There is a strong correlation between family history and obesity. Inividuals with obese family members have a higher risk of becoming obese themselves.
#
# These conclusions highlight the importance of lifestyle choices in managing obesity. Regular screening and healthy lifestyle choices are crucial in mitigating risks associated with obesity.
